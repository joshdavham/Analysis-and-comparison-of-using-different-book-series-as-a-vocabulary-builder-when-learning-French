# %%
import pandas as pd

#functions used for the simulation
from functions import *

# %%
#Frequency list of all French words
freq_list = pd.read_csv('freq_list.csv')

# %% [markdown]
# # The Simulation

# %% [markdown]
# ## Percy Jackson

# %%
#a list of all the percy jackson books we will consider for the analysis
books_list = ['Percy Jackson/1/','Percy Jackson/2/','Percy Jackson/3/']

#load the relevant book and word-frequency data for the simulation
book_dfs, freq_list_series = load_data(books_list)

#run the simulation beginning with knowledge of the most common 5000 words
vocab_size_init = 5000
learned_words_data_PJ, known_words_PJ = one_T_simulation(books_list, book_dfs, freq_list, freq_list_series, vocab_size_init)
# Out:
# Initial Vocabulary Size: 5000 words.
# ------------------------------------
#
# Percy Jackson 1
# -Vocabulary Size after reading Book: 7418
#
# Percy Jackson 2
# -Vocabulary Size after reading Book: 9038
#
# Percy Jackson 3
# -Vocabulary Size after reading Book: 10721

# %%
learned_words_data_PJ
# Out:
#    Book Chapter Num_Words Num_Unknown Vocab_Before Vocab_After
# 0     1       1      3777         481         5000        5083
# 1     1       2      3002         329         5083        5177
# 2     1       3      4151         398         5177        5265
# 3     1       4      3340         359         5265        5339
# 4     1       5      4853         518         5339        5466
# ..  ...     ...       ...         ...          ...         ...
# 57    3      16      5100         254        10363       10458
# 58    3      17      3747         183        10458       10547
# 59    3      18      2011          85        10547       10587
# 60    3      19      4257         208        10587       10677
# 61    3      20      3037          76        10677       10721
#
# [62 rows x 6 columns]

# %% [markdown]
# ### Save the data

# %%
learned_words_data_PJ.to_csv('Percy Jackson/learned_words_data.csv', index=False)
known_words_PJ.to_csv('Percy Jackson/known_words.csv', index=True)

# %% [markdown]
# ## Harry Potter

# %%
#a list of all the harry potter books we will consider for the analysis
books_list = ['Harry Potter/1/','Harry Potter/2/','Harry Potter/3/']

#load the relevant book and word-frequency data for the simulation
book_dfs, freq_list_series = load_data(books_list)

#run the simulation beginning with knowledge of the most common 5000 words
vocab_size_init = 5000
learned_words_data_HP, known_words_HP = one_T_simulation(books_list, book_dfs, freq_list, freq_list_series, vocab_size_init)
# Out:
# Initial Vocabulary Size: 5000 words.
# ------------------------------------
#
# Harry Potter 1
# -Vocabulary Size after reading Book: 6719
#
# Harry Potter 2
# -Vocabulary Size after reading Book: 8393
#
# Harry Potter 3
# -Vocabulary Size after reading Book: 10255

# %%
learned_words_data_HP
# Out:
#    Book Chapter Num_Words Num_Unknown Vocab_Before Vocab_After
# 0     1       1      5332         512         5000        5101
# 1     1       2      3920         312         5101        5175
# 2     1       3      4305         392         5175        5274
# 3     1       4      4259         339         5274        5366
# 4     1       5      6978         755         5366        5513
# 5     1       6      6766         554         5513        5624
# 6     1       7      4706         403         5624        5736
# 7     1       8      3257         332         5736        5792
# 8     1       9      5263         394         5792        5911
# 9     1      10      4484         359         5911        6017
# 10    1      11      3309         274         6017        6090
# 11    1      12      5714         412         6090        6183
# 12    1      13      3367         214         6183        6254
# 13    1      14      3586         266         6254        6334
# ...

# %% [markdown]
# ### Save the data

# %%
learned_words_data_HP.to_csv('Harry Potter/learned_words_data.csv', index=False)
known_words_HP.to_csv('Harry Potter/known_words.csv', index=True)

# %% [markdown]
# ## Hunger Games

# %%
#a list of all the harry potter books we will consider for the analysis
books_list = ['Hunger Games/1/','Hunger Games/2/','Hunger Games/3/']

#load the relevant book and word-frequency data for the simulation
book_dfs, freq_list_series = load_data(books_list)

#run the simulation beginning with knowledge of the most common 5000 words
vocab_size_init = 5000
learned_words_data_HG, known_words_HG = one_T_simulation(books_list, book_dfs, freq_list, freq_list_series, vocab_size_init)
# Out:
# Initial Vocabulary Size: 5000 words.
# ------------------------------------
#
# Hunger Games 1
# -Vocabulary Size after reading Book: 7433
#
# Hunger Games 2
# -Vocabulary Size after reading Book: 9697
#
# Hunger Games 3
# -Vocabulary Size after reading Book: 11883

# %%
learned_words_data_HG
# Out:
#    Book Chapter Num_Words Num_Unknown Vocab_Before Vocab_After
# 0     1       1      5194         704         5000        5089
# 1     1       2      3529         406         5089        5176
# 2     1       3      3756         435         5176        5271
# 3     1       4      3667         392         5271        5347
# 4     1       5      3243         413         5347        5425
# ..  ...     ...       ...         ...          ...         ...
# 77    3      24      5284         318        11519       11633
# 78    3      25      3217         156        11633       11699
# 79    3      26      3883         152        11699       11776
# 80    3      27      5054         218        11776       11877
# 81    3      28       345          19        11877       11883
#
# [82 rows x 6 columns]

# %% [markdown]
# ### Save the data

# %%
learned_words_data_HG.to_csv('Hunger Games/learned_words_data.csv', index=False)
known_words_HG.to_csv('Hunger Games/known_words.csv', index=True)
